# %%
import re
import os
import warnings

import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"\\src")

import numpy as np
import pandas as pd
from pymystem3 import Mystem
from nltk.corpus import stopwords

# %%
mystem = Mystem()
swords = set(stopwords.words('russian'))

# %%
from text_preprocess import lemm_file
root = 'komersant_business'
files = sorted(os.listdir(f'{root}/raw_cites'))
files = [f for f in files if f[0] != '.']
c = 1

for file in files:
    if file == '13726.pkl':
        continue
    print(f'file {file} in work')
    df = lemm_file(root, f'/{file}')
    if df is None:
        continue
    df.to_csv(f'{root}/prep_cites/{file[:-4]}.csv', index=False)
    print(f'{c} из {len(files)} готов')
    c += 1
# Out:
# file 17800.pkl in work
# title ready
# announce ready
# text ready
# 1 из 283 готов
# file 1800.pkl in work
# title ready
# announce ready
# text ready
# 2 из 283 готов
# file 18000.pkl in work
# title ready
# announce ready
# text ready
# 3 из 283 готов
# file 18200.pkl in work
# title ready
# announce ready
# text ready
# 4 из 283 готов
# file 18400.pkl in work
# title ready
# announce ready
# text ready
# 5 из 283 готов
# file 18600.pkl in work
# title ready
# announce ready
# text ready
# 6 из 283 готов
# file 18800.pkl in work
# title ready
# announce ready
# text ready
# 7 из 283 готов
# file 19000.pkl in work
# title ready
# announce ready
# text ready
# 8 из 283 готов
# file 19200.pkl in work
# title ready
# announce ready
# text ready
# 9 из 283 готов
# file 19400.pkl in work
# title ready
# announce ready
# text ready
# 10 из 283 готов
# file 19600.pkl in work
# title ready
# announce ready
# text ready
# 11 из 283 готов
# file 19800.pkl in work
# title ready
# ...

# %%
from text_preprocess import preprocess_tg
files = os.listdir('Telegram data')
if '.DS_Store' in files:
    files.remove('.DS_Store')
c = 1

for file in files:
    print(f'file {file} in work')
    warnings.filterwarnings('ignore')
    df = preprocess_tg(f'/{file}')
    warnings.filterwarnings('default')
    df.to_csv(f'Telegram prep/{file[:-4]}csv', index=False)
    print(f'{c} из {len(files)} готов')
    c += 1

# %% [markdown]
# ## Получаем ссылки, которые не удалось скачать

# %%
from text_preprocess import get_unparsed_urls
get_unparsed_urls('komersant_politics')

# %% [markdown]
# ### Обрабатываем даты, чтобы они везде были стандартные

# %%
from text_preprocess import vedomosti_to_standard_date
folders = ['vedomosti_' + i for i in [
    'business', 
    'economics', 
    'finance',
    'invest', 
    'personal_account']]
vedomosti_to_standard_date(folders)
# Out:
# vedomosti_finance в работе
# 100 из 128 обработано

# %%
from text_preprocess import ria_to_standard_date
folders = ['ria_economy', 'ria_politics']
ria_to_standard_date(folders)
# Out:
# ria_economy в работе
# 100 из 1292 обработано
# 200 из 1292 обработано
# 300 из 1292 обработано
# 400 из 1292 обработано
# 500 из 1292 обработано
# 600 из 1292 обработано
# 700 из 1292 обработано
# 800 из 1292 обработано
# 900 из 1292 обработано
# 1000 из 1292 обработано
# 1100 из 1292 обработано
# 1200 из 1292 обработано
# ria_politics в работе
# 100 из 527 обработано
# 200 из 527 обработано
# 300 из 527 обработано
# 400 из 527 обработано
# 500 из 527 обработано

# %%
from text_preprocess import lenta_to_standard_date
lenta_to_standard_date(['lenta_economy'])
# Out:
# Обработано 100 из 250
# Обработано 200 из 250

# %%
from text_preprocess import telegram_to_standard_date
telegram_to_standard_date()
# Out:
# /var/folders/m6/2n44mlkj7nbdwb651dd78pwc0000gn/T/ipykernel_902/2798297056.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'Telegram prep/{file}')

# %%
from text_preprocess import komersant_to_standard_date
folders = ['komersant_' + t for t in ['economics', 'politics', 'consumer_market', 'business', 'finance']]

komersant_to_standard_date(folders)
# Out:
# Обработано 100 из 327
# Обработано 200 из 327
# Обработано 300 из 327
# Обработано 100 из 187

# %% [markdown]
# ### Собираем данные под обучение

# %%
companies = {
    'ALRS': 'alrosa-ao', 'AFLT': 'aeroflot', 'VTBR': 'vtb', 'GAZP' : 'gazprom', 'GMKN': 'nornickel-gmk', 'LSRG': 'lsr', 
    'DSKY': 'detsky-mir', 'IRAO': 'inter-rao-ao', 'LKOH': 'lukoil', 'MAGN': 'mmk', 'MOEX': 'moscowexchange', 'CBOM': 'oao-mkb-ao', 
    'MTSS': 'mts', 'VKCO': 'gdr-vk-company-limited-ord-shs_vkco-tqbr', 'ROSN': 'rosneft', 'NLMK': 'nlmk-ao', 'NVTK': 'novatek', 'PIKK': 'pik', 
    'PLZL': 'polus-zoloto', 'RTKM': 'rostelecom', 'RUAL': 'united-company-rusal-plc', 'HYDR': 'rusgidro', 'SBER': 'sberbank', 'CHMF': 'severstal-ao', 
    'AFKS': 'afk-sistema', 'SNGS': 'surgut', 'TATN': 'tatneft-3', 'TCSG': 'gdr-tcs-group-holding-ord-shs_tcsg', 'TRNFP': 'transneft-pref', 
    'POGR': 'petropavlovsk-plc_pogr', 'PHOR': 'phosagro-ao', 'FEES': 'fsk-ees', 'HHRU': 'adr-headhunter-group-ord-shs_hhru', 'YNDX': 'pllc-yandex-n-v'}

# %%
#Собираем данные дат в один файл
folders = os.listdir('Стоимость акций')
folders = [f for f in folders if f[0] != '.']
folders.remove('5 мин.')
folders.remove('15 мин.')
for folder in folders:
    for company in companies:
        files = os.listdir(f'Стоимость акций/{folder}')
        files = [f for f in files if company in f and '0101' in f]
        data = pd.DataFrame()
        for file in files:
            try:
                tmp = pd.read_csv(f'Стоимость акций/{folder}/{file}', sep=';')[['<DATE>', '<TIME>', '<CLOSE>']]
                if folder == '1 день':
                    time = tmp['<DATE>'].astype(str)
                    tmp['timestamp'] = pd.to_datetime(time, format='%Y%m%d')
                    tmp.sort_values('timestamp', inplace=True)
                elif folder == '1 час':
                    time = tmp['<DATE>'].astype(str) + tmp['<TIME>'].astype(str).map(lambda x: '235000' if x == '0' else x)
                    tmp['timestamp'] = pd.to_datetime(time, format='%Y%m%d%H%M%S')
                    tmp.sort_values('timestamp', inplace=True)
                else:
                    time = tmp['<DATE>'].astype(str) + tmp['<TIME>'].astype(str).map(lambda x: '235000' if x == '0' else x)
                    tmp['timestamp'] = pd.to_datetime(time, format='%Y%m%d%H%M%S')
                    tmp.sort_values('timestamp', inplace=True)

                tmp.drop(columns=['<DATE>', '<TIME>'], inplace=True)
                tmp.columns = ['close', 'timestamp']
                tmp.sort_values('timestamp', inplace=True)
                data = pd.concat([data, tmp], axis=0)
            except Exception as ex:
                print(folder)
                print(file)
                print(ex)
        data.to_csv(f'Стоимость акций/{folder}/{company}.csv', index=False)
        print(f'{company} готов')
# Out:
# 1 час
# ALRS_100101_110101.csv
# No columns to parse from file
# ALRS готов
# AFLT готов
# VTBR готов
# GAZP готов
# GMKN готов
# LSRG готов
# 1 час
# DSKY_160101_170101.csv
# No columns to parse from file
# 1 час
# DSKY_140101_150101.csv
# No columns to parse from file
# 1 час
# DSKY_130101_140101.csv
# No columns to parse from file
# 1 час
# DSKY_150101_160101.csv
# No columns to parse from file
# 1 час
# DSKY_100101_110101.csv
# No columns to parse from file
# 1 час
# DSKY_120101_130101.csv
# No columns to parse from file
# 1 час
# DSKY_110101_120101.csv
# No columns to parse from file
# DSKY готов
# IRAO готов
# LKOH готов
# MAGN готов
# 1 час
# MOEX_100101_110101.csv
# No columns to parse from file
# 1 час
# MOEX_120101_130101.csv
# No columns to parse from file
# 1 час
# MOEX.VKCO_TQBR_130101_140101.csv
# No columns to parse from file
# 1 час
# MOEX_110101_120101.csv
# No columns to parse from file
# 1 час
# MOEX.VKCO_TQBR_110101_120101.csv
# No columns to parse from file
# ...

# %% [markdown]
# ### Мэтчим новость и дату

# %%
from text_preprocess import add_target
folders = ['komersant_' + t for t in ['economics', 'politics', 'consumer_market','business', 'finance']] + \
    ['vedomosti_' + t for t in ['business', 'economics', 'finance', 'invest', 'personal_account']] + \
            ['ria_economy', 'ria_politics',
             'lenta_economy']
folders = ['vedomosti_personal_account'] +  ['ria_economy', 'ria_politics', 'lenta_economy']

for folder in folders:
    add_target(folder)
    print(f'{folder} готов')

# %%
from text_preprocess import add_target_bin
for folder in folders:
    add_target_bin(folder)
    print(f'{folder} готов')
# Out:
# ALRS готов
# AFLT готов
# VTBR готов
# GAZP готов
# GMKN готов
# LSRG готов
# DSKY готов
# IRAO готов
# LKOH готов
# MAGN готов
# MOEX готов
# CBOM готов
# MTSS готов
# VKCO готов
# ROSN готов
# NLMK готов
# NVTK готов
# PIKK готов
# PLZL готов
# RTKM готов
# RUAL готов
# HYDR готов
# SBER готов
# CHMF готов
# AFKS готов
# SNGS готов
# TATN готов
# TCSG готов
# TRNFP готов
# POGR готов
# PHOR готов
# FEES готов
# HHRU готов
# YNDX готов
# vedomosti_personal_account готов
# ALRS готов
# AFLT готов
# VTBR готов
# GAZP готов
# GMKN готов
# LSRG готов
# DSKY готов
# IRAO готов
# LKOH готов
# MAGN готов
# MOEX готов
# CBOM готов
# MTSS готов
# VKCO готов
# ROSN готов
# NLMK готов
# NVTK готов
# PIKK готов
# PLZL готов
# RTKM готов
# RUAL готов
# HYDR готов
# SBER готов
# CHMF готов
# AFKS готов
# SNGS готов
# TATN готов
# TCSG готов
# TRNFP готов
# POGR готов
# PHOR готов
# FEES готов
# HHRU готов
# YNDX готов
# ria_economy готов
# ALRS готов
# AFLT готов
# VTBR готов
# GAZP готов
# ...

# %%
from text_preprocess import add_target_tg
add_target_tg()
# Out:
# ALRS готов
# AFLT готов
# VTBR готов
# GAZP готов
# GMKN готов
# LSRG готов
# DSKY готов
# IRAO готов
# LKOH готов
# MAGN готов
# MOEX готов
# CBOM готов
# MTSS готов
# VKCO готов
# ROSN готов
# NLMK готов
# NVTK готов
# PIKK готов
# PLZL готов
# RTKM готов
# RUAL готов
# HYDR готов
# SBER готов
# CHMF готов
# AFKS готов
# SNGS готов
# TATN готов
# TCSG готов
# TRNFP готов
# POGR готов
# PHOR готов
# FEES готов
# HHRU готов
# YNDX готов
# ALRS готов
# AFLT готов
# VTBR готов
# GAZP готов
# GMKN готов
# LSRG готов
# DSKY готов
# IRAO готов
# LKOH готов
# MAGN готов
# MOEX готов
# CBOM готов
# MTSS готов
# VKCO готов
# ROSN готов
# NLMK готов
# NVTK готов
# PIKK готов
# PLZL готов
# RTKM готов
# RUAL готов
# HYDR готов
# SBER готов
# CHMF готов
# AFKS готов
# SNGS готов
# TATN готов
# TCSG готов
# TRNFP готов
# POGR готов
# PHOR готов
# FEES готов
# HHRU готов
# YNDX готов
# ALRS готов
# AFLT готов
# VTBR готов
# GAZP готов
# GMKN готов
# LSRG готов
# DSKY готов
# IRAO готов
# ...

# %%
from text_preprocess import add_target_bin_tg
add_target_bin_tg()
# Out:
# ALRS готов
# AFLT готов
# VTBR готов
# GAZP готов
# GMKN готов
# LSRG готов
# DSKY готов
# IRAO готов
# LKOH готов
# MAGN готов
# MOEX готов
# CBOM готов
# MTSS готов
# VKCO готов
# ROSN готов
# NLMK готов
# NVTK готов
# PIKK готов
# PLZL готов
# RTKM готов
# RUAL готов
# HYDR готов
# SBER готов
# CHMF готов
# AFKS готов
# SNGS готов
# TATN готов
# TCSG готов
# TRNFP готов
# POGR готов
# PHOR готов
# FEES готов
# HHRU готов
# YNDX готов
# ALRS готов
# AFLT готов
# VTBR готов
# GAZP готов
# GMKN готов
# LSRG готов
# DSKY готов
# IRAO готов
# LKOH готов
# MAGN готов
# MOEX готов
# CBOM готов
# MTSS готов
# VKCO готов
# ROSN готов
# NLMK готов
# NVTK готов
# PIKK готов
# PLZL готов
# RTKM готов
# RUAL готов
# HYDR готов
# SBER готов
# CHMF готов
# AFKS готов
# SNGS готов
# TATN готов
# TCSG готов
# TRNFP готов
# POGR готов
# PHOR готов
# FEES готов
# HHRU готов
# YNDX готов
# ALRS готов
# AFLT готов
# VTBR готов
# GAZP готов
# GMKN готов
# LSRG готов
# DSKY готов
# IRAO готов
# ...

# %% [markdown]
# ### Колонки для определения принадлежности новости к компании

# %%
companies = {
    'ALRS': 'alrosa-ao', 'AFLT': 'aeroflot', 'VTBR': 'vtb', 'GAZP' : 'gazprom', 'GMKN': 'nornickel-gmk', 'LSRG': 'lsr', 
    'DSKY': 'detsky-mir', 'IRAO': 'inter-rao-ao', 'LKOH': 'lukoil', 'MAGN': 'mmk', 'MOEX': 'moscowexchange', 'CBOM': 'oao-mkb-ao', 
    'MTSS': 'mts', 'VKCO': 'gdr-vk-company-limited-ord-shs_vkco-tqbr', 'ROSN': 'rosneft', 'NLMK': 'nlmk-ao', 
    'NVTK': 'novatek', 
    'PIKK': 'pik', 
    'PLZL': 'polus-zoloto', 'RTKM': 'rostelecom', 
    'RUAL': 'united-company-rusal-plc', 
    'HYDR': 'rusgidro', 'SBER': 'sberbank', 'CHMF': 'severstal-ao', 
    'AFKS': 'afk-sistema', 'SNGS': 'surgut', 'TATN': 'tatneft-3', 'TCSG': 'gdr-tcs-group-holding-ord-shs_tcsg', 'TRNFP': 'transneft-pref', 
    'POGR': 'petropavlovsk-plc_pogr', 
    'PHOR': 'phosagro-ao', 
    'FEES': 'fsk-ees', 'HHRU': 'adr-headhunter-group-ord-shs_hhru', 'YNDX': 'pllc-yandex-n-v'
}

# %%
for_regex = {
    'ALRS': ['алроса', 'alrs'], 'AFLT': ['аэрофлот', 'aflt'], 'VTBR': ['втб', 'vtbr'], 'GAZP': ['газпром', 'gazp'], 
'GMKN': ['норникель', 'норильский никель', 'gmkn'], 'LSRG': ['лср', 'lsrg'], 'DSKY': ['детский мир', 'dsky'], 'IRAO': ['интер рао', 'irao'],
'LKOH': ['лукойл', 'lkoh'], 'MAGN': ['ммк', 'магнитогорский металлургический комбинат', 'magn'], 'MOEX': ['пао московский биржа', 'moex'],
'CBOM': ['мкб', 'московский кредитный банк', 'cbom'], 'MTSS': ['мтс', 'mtss'], 'VKCO': ['вк', 'мэйл', 'вконтакте', 'mail', 'vk', 'vkco'], 
'ROSN': ['роснефть', 'rosn'], 'NLMK': ['nlmk', 'новолипецкий металлургический комбинат'],
             'NVTK': ['новатэк', 'nvtk'], 
'PIKK': ['пик', 'pikk'], 'PLZL': ['plzl', 'полюс золото'], 'RTKM': ['ростелеком', 'rtkm'], 
    'RUAL': ['русал', 'rual', 'rusal', 'uc rusal'], 
'HYDR': ['русгидро', 'hydr'], 'SBER': ['/^сбер$/', 'сбербанк', 'sber'], 'CHMF': ['северсталь', 'chmf'], 'AFKS': ['афк', 'afks'],
'SNGS': ['сургутнефтегаз', 'sngs'], 'TATN': ['tatn', 'татнефть'], 'TCSG': ['tcsg', 'тинькофф'], 'TRNFP': ['транснефть', 'trnfp'],
'POGR': ['петропавловск золото', 'petropavlovsk plc', 'petropavlovsk', 'pogr'], 
    'PHOR': ['фосагро', 'phor'], 'FEES': ['фск еэс', 'fees'], 
'HHRU': ['headhunter', 'hhru'], 'YNDX': ['яндекс', 'yandex', 'yndx']
}

# %%
def add_company(roots, for_regex, companies):
    for root in roots:
        df = pd.read_csv(f'{root}/{root}.csv')
        for company in companies:
            reg = for_regex[company]
            reg = ' | '.join(reg)
            in_str = df['title'].str.contains(reg) | df['announce'].str.contains(reg) | df['text'].str.contains(reg)
            df[company] = in_str
        df.to_csv(f'{root}/{root}.csv', index=False)
        print(f'{root} done')
        

def add_company_tg(for_regex, companies):
    files = os.listdir('Telegram prep')
    files.remove('messages')
    if '.DS_Store' in files:
        files.remove('.DS_Store')
    for file in files:
        df = pd.read_csv(f'Telegram prep/{file}')
        for company in companies:
            reg = for_regex[company]
            reg = ' | '.join(reg)
            in_str = df['message'].str.contains(reg)
            df[company] = in_str
        df.to_csv(f'Telegram prep/{file}', index=False)
        print(f'{file} done')
        
        
def add_industry(roots, industries, for_regex_industry):
    for root in roots:
        df = pd.read_csv(f'{root}/{root}.csv')
        for industry in industries:
            reg = for_regex_industry[industry]
            reg = ' | '.join(reg)
            in_str = df['title'].str.contains(reg) | df['announce'].str.contains(reg) | df['text'].str.contains(reg)
            df[industry] = in_str
        df.to_csv(f'{root}/{root}.csv', index=False)
        print(f'{root} done')

# %%
folders = ['komersant_business', 'komersant_consumer_market', 'komersant_economics', 'komersant_finance', 'komersant_politics',
        'lenta_economy', 'ria_economy', 'ria_politics',
        'vedomosti_business', 'vedomosti_economics', 'vedomosti_finance', 'vedomosti_invest', 'vedomosti_personal_account']
roots = ['C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/' + el for el in folders]

# %%
# company = 'SBER'
# for root, folder in zip(roots, folders):
#     data = pd.read_parquet(root + '/' + folder + '_data.parquet')
#     comps = pd.read_parquet(root + '/' + folder + '_company.parquet')
#     reg = for_regex[company]
#     reg = ' | '.join(reg)
#     in_str = data['title'].str.contains(reg) | data['announce'].str.contains(reg) | data['text'].str.contains(reg)
#     comps[company] = in_str
#     comps.to_parquet(root + '/' + folder + '_company.parquet', index=False)
#     del data
#     print(f'{root} done')
# Out:
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/komersant_business done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/komersant_consumer_market done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/komersant_economics done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/komersant_finance done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/komersant_politics done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/lenta_economy done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/ria_economy done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/ria_politics done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/vedomosti_business done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/vedomosti_economics done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/vedomosti_finance done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/vedomosti_invest done
# ...

# %%
# sec = 'finance'
# for root, folder in zip(roots, folders):
#     data = pd.read_parquet(root + '/' + folder + '_data.parquet')
#     sector = pd.read_parquet(root + '/' + folder + '_sector.parquet')
#     reg = for_regex_industry[sec]
#     reg = ' | '.join(reg)
#     in_str = data['title'].str.contains(reg) | data['announce'].str.contains(reg) | data['text'].str.contains(reg)
#     sector[sec] = in_str
#     sector.drop(columns=[company], inplace=True)
#     sector.to_parquet(root + '/' + folder + '_sector.parquet', index=False)
#     del data
#     del sector
#     print(f'{root} done')
# Out:
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/komersant_business done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/komersant_consumer_market done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/komersant_economics done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/komersant_finance done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/komersant_politics done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/lenta_economy done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/ria_economy done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/ria_politics done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/vedomosti_business done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/vedomosti_economics done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/vedomosti_finance done
# C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/vedomosti_invest done
# ...

# %%
# tg_root = 'C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/Telegram prep'
# import os
# folders = os.listdir(tg_root)
# folders = [f for f in folders if 'csv' not in f]

# %%
# company = 'SBER'
# for folder in folders:
#     data = pd.read_parquet(tg_root + '/' + folder + '/' + f'{folder}_data.parquet')
#     comps = pd.read_parquet(tg_root + '/' + folder + '/' + f'{folder}_company.parquet')
#     reg = for_regex[company]
#     reg = ' | '.join(reg)
#     in_str = data['message'].str.contains(reg)
#     comps[company] = in_str
#     comps.to_parquet(tg_root + '/' + folder + '/' + f'{folder}_company.parquet', index=False)
#     del data
#     del comps
#     print(f'{folder} done')
# Out:
# ak47pfl done
# antiskrepa done
# banksta done
# bitkogan done
# cbonds done
# cbrstocks done
# divForever done
# DividendNews100 done
# economika done
# economylive done
# energytodaygroup done
# FatCat18 done
# finascop done
# gazmyaso done
# gazprom done
# gazpromneft_official done
# information_disclosure done
# investingcorp done
# kotelviry done
# kremlin_mother_expert done
# marketoverview done
# markettwits done
# mislinemisli done
# moscowexchangeofficial done
# nebrexnya done
# nedvizhna24 done
# papagaz done
# rbc_news done
# rian_ru done
# rt_russian done
# russianmacro done
# smartlab done
# smartlabnews done
# StockNews100 done

# %%
# sec = 'finance'
# for folder in folders:
#     data = pd.read_parquet(tg_root + '/' + folder + '/' + f'{folder}_data.parquet')
#     sector = pd.read_parquet(tg_root + '/' + folder + '/' + f'{folder}_sector.parquet')
#     reg = for_regex_industry[sec]
#     reg = ' | '.join(reg)
#     in_str = data['message'].str.contains(reg)
#     sector[sec] = in_str
#     sector.to_parquet(tg_root + '/' + folder + '/' + f'{folder}_sector.parquet', index=False)
#     del data
#     del sector
#     print(f'{folder} done')
# Out:
# ak47pfl done
# antiskrepa done
# banksta done
# bitkogan done
# cbonds done
# cbrstocks done
# divForever done
# DividendNews100 done
# economika done
# economylive done
# energytodaygroup done
# FatCat18 done
# finascop done
# gazmyaso done
# gazprom done
# gazpromneft_official done
# information_disclosure done
# investingcorp done
# kotelviry done
# kremlin_mother_expert done
# marketoverview done
# markettwits done
# mislinemisli done
# moscowexchangeofficial done
# nebrexnya done
# nedvizhna24 done
# papagaz done
# rbc_news done
# rian_ru done
# rt_russian done
# russianmacro done
# smartlab done
# smartlabnews done
# StockNews100 done

# %%
from text_preprocess import add_company
add_company(roots, for_regex, companies)
# Out:
# komersant_business done
# komersant_consumer_market done
# komersant_economics done
# komersant_finance done
# komersant_politics done
# lenta_economy done
# ria_economy done
# ria_politics done
# vedomosti_business done
# vedomosti_economics done
# vedomosti_finance done
# vedomosti_invest done
# vedomosti_personal_account done

# %%
from text_preprocess import add_company_tg
add_company_tg(for_regex, companies)
# Out:
# markettwits.csv done
# rian_ru.csv done
# information_disclosure.csv done
# moscowexchangeofficial.csv done
# smartlab.csv done
# cbonds.csv done
# economylive.csv done
# cbrstocks.csv done
# gazmyaso.csv done
# divForever.csv done
# FatCat18.csv done
# kremlin_mother_expert.csv done
# DividendNews100.csv done
# smartlabnews.csv done
# rt_russian.csv done
# mislinemisli.csv done
# marketoverview.csv done
# kotelviry.csv done
# nedvizhna24.csv done
# gazpromneft_official.csv done
# finascop.csv done
# StockNews100.csv done
# russianmacro.csv done
# investingcorp.csv done
# gazprom.csv done
# papagaz.csv done
# banksta.csv done
# energytodaygroup.csv done
# nebrexnya.csv done
# antiskrepa.csv done
# rbc_news.csv done
# ak47pfl.csv done
# economika.csv done
# bitkogan.csv done

# %%
for_regex_industry = {
    'finance': ['ипотека', 'sber', '/^сбер$/', 'сбербанк', 'банк', 'кредит', 'депозит', 'мкб', 'московский кредитный банк', 'cbom', 'vtbr', 'втб', 'финансовый', 'финансы', 'биржа', 'moex', 'tcsg', 'тинькофф'],
     'gold': ['poly', 'plzl', 'полиметалл', 'полюс золото', 'золото', 'pogr', 'petropavlovsk plc', 'petropavlovsk'],
     'ferrous_metallurgy': ['железо', 'сталь', 'северсталь', 'чугун', 'ммк', 'магнитогорский металлургический комбинат', 'magn', 'северсталь', 'chmf', 'nlmk', 'новолипецкий металлургический комбинат', 'металл'],
     'oil_gas':['gazp', 'газпром', 'rosn', 'роснефть', 'сургутнефтегаз', 'sngs', 'газ', 'нефть', 'нефтепровод', 'газопровод', 'татнефть', 'tatn', 'лукойл', 'lkoh', 'транснефть', 'trnfp', 'новатэк', 'nvtk'],
     'non_ferrous_metallurgy': ['rual', 'rusal', 'uc rusal','русал', 'gmkn', 'норникель', 'норильский никель', 'ниель', 'алюминий', 'палладий', 'олово', 'медь', 'глинозем'],
     'electrical networks': ['интер рао', 'irao', 'русгидро', 'hydr', 'элетричество', 'гэс', 'тэц', 'энергетика', 'фск еэс', 'fees'],
     'telecom': ['мтс', 'mtss', 'ростелеком', 'rtkm', 'сеть', 'связь', 'интернет', 'провайдер'],
     'it': ['машинный обучение', 'цифровой технология', 'облако', 'вк', 'мэйл', 'вконтакте', 'mail', 'vk', 'vkco', 'яндекс', 'yandex', 'yndx'],
     'real_estate': ['недвижимость', 'новостройка', 'ипотека', 'лср', 'lsrg', 'пик', 'pikk']
}

industries = for_regex_industry.keys()

# %%
from text_preprocess import add_industry, add_industry_tg
add_industry(roots, industries, for_regex_industry)
add_industry_tg(industries, for_regex_industry)
# Out:
# komersant_business done
# komersant_consumer_market done
# komersant_economics done
# komersant_finance done
# komersant_politics done
# lenta_economy done
# ria_economy done
# ria_politics done
# vedomosti_business done
# vedomosti_economics done
# vedomosti_finance done
# vedomosti_invest done
# vedomosti_personal_account done
# markettwits.csv done
# rian_ru.csv done
# information_disclosure.csv done
# moscowexchangeofficial.csv done
# smartlab.csv done
# cbonds.csv done
# economylive.csv done
# cbrstocks.csv done
# gazmyaso.csv done
# divForever.csv done
# FatCat18.csv done
# kremlin_mother_expert.csv done
# DividendNews100.csv done
# smartlabnews.csv done
# rt_russian.csv done
# mislinemisli.csv done
# marketoverview.csv done
# kotelviry.csv done
# nedvizhna24.csv done
# gazpromneft_official.csv done
# finascop.csv done
# StockNews100.csv done
# russianmacro.csv done
# investingcorp.csv done
# gazprom.csv done
# papagaz.csv done
# banksta.csv done
# energytodaygroup.csv done
# ...

# %% [markdown]
# ### Собираем итоговый Датасет

# %%
### Традиционные новости
folders = ['komersant_business', 'komersant_consumer_market', 'komersant_economics', 'komersant_finance', 'komersant_politics',
        'lenta_economy', 'ria_economy', 'ria_politics',
        'vedomosti_business', 'vedomosti_economics', 'vedomosti_finance', 'vedomosti_invest', 'vedomosti_personal_account']
roots = ['C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/' + el for el in folders]
files = os.listdir(roots[0])
files = [f for f in files if 'parquet' in f]

# %%
agg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 671315 entries, 0 to 1054
# Columns: 525 entries, link to source
# dtypes: bool(281), datetime64[ns](1), float64(238), object(5)
# memory usage: 1.4+ GB

# %%
import warnings
warnings.simplefilter('ignore')
agg_df = pd.DataFrame()
for root, folder in zip(roots, folders):
    files = [
        folder + el + '.parquet' for el in ['_data', '_abs_values', '_rel_values', '_company', '_sector']
    ]
    tmp_agg_df = pd.DataFrame()
    for file in files:
        tmp = pd.read_parquet(root + '/' + file)
        tmp.columns = tmp.columns.str.replace('.1', '')
        tmp = tmp.loc[:,~tmp.columns.duplicated()].copy()
        tmp_agg_df = pd.concat([tmp_agg_df, tmp], axis=1)
    tmp_agg_df = tmp_agg_df.loc[:,~tmp_agg_df.columns.duplicated()].copy()
    tmp_agg_df['source'] = folder
    agg_df = pd.concat([agg_df, tmp_agg_df])
    print(folder)
agg_df.to_parquet('C:/Users/ап/Рабочий стол/Жора/Диссертация/Data/news.parquet', index=False)
warnings.simplefilter('default')
# Out:
# komersant_business
# komersant_consumer_market
# komersant_economics
# komersant_finance
# komersant_politics
# lenta_economy
# ria_economy
# ria_politics
# vedomosti_business
# vedomosti_economics
# vedomosti_finance
# vedomosti_invest
# vedomosti_personal_account
# ---------------------------------------------------------------------------
# ArrowMemoryError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23828\2258034496.py in <module>
#      16     agg_df = pd.concat([agg_df, tmp_agg_df])
#      17     print(folder)
# ---> 18 agg_df.to_parquet('C:/Users/ап/Рабочий стол/Жора/Диссертация/Data/news.parquet', index=False)
#      19 warnings.simplefilter('default')
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
# ...

# %%
agg_df.to_parquet('C:/Users/ап/Рабочий стол/Жора/Диссертация/Data/news.parquet', engine='fastparquet', index=False)

# %%
tg_root = 'C:/Users/ап/Рабочий стол/Жора/Диссертация/Парсеры сайтов/Telegram prep'
import os
folders = os.listdir(tg_root)
folders = [f for f in folders if 'csv' not in f]

# %%
### Телеграмм
agg_df = pd.DataFrame()
for folder in folders:
    files = [
        folder + el + '.parquet' for el in ['_data', '_abs_values', '_rel_values', '_company', '_sector']
    ]
    tmp_agg_df = pd.DataFrame()
    for file in files:
        tmp = pd.read_parquet(tg_root + '/' + folder + '/' + file)
        tmp_agg_df = pd.concat([tmp_agg_df, tmp], axis=1)
    tmp_agg_df['source'] = folder
    agg_df = pd.concat([agg_df, tmp_agg_df])
    print(folder)
agg_df.to_parquet('C:/Users/ап/Рабочий стол/Жора/Диссертация/Data/tg.parquet', index=False)
# Out:
# ak47pfl
# antiskrepa
# banksta
# bitkogan
# cbonds
# cbrstocks
# divForever
# DividendNews100
# economika
# economylive
# energytodaygroup
# FatCat18
# finascop
# gazmyaso
# gazprom
# gazpromneft_official
# information_disclosure
# investingcorp
# kotelviry
# kremlin_mother_expert
# marketoverview
# markettwits
# mislinemisli
# moscowexchangeofficial
# nebrexnya
# nedvizhna24
# papagaz
# rbc_news
# rian_ru
# rt_russian
# russianmacro
# smartlab
# smartlabnews
# StockNews100
